# %% [markdown]
# <div style="font-weight: bold; color:#5D8AA8" align="center">
#     <div style="font-size: xx-large; color:gray"> Annotation Results analysis </div><br> </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# RUN THIS NOTEBOOK FROM THE Modelo_11_estados FOLDER!
print(f"Remember working directory: {os.getcwd()}")
input_folder="my_results/GO_enrichment"
# Out:
# Remember working directory: /home/ines/Escritorio/epigCTCF

# %% [markdown]
# ### (1) **GO enrichment files**

# %% [markdown]
# #### GO: **Biological Process**

# %%
biological_processes_df = pd.read_csv(f"{input_folder}/BP_enriched_genes_entrez.txt.tsv", sep="\t", index_col=0, header="infer")
print(f"biological_processes_df.shape: {biological_processes_df.shape}")
print(f"biological_processes_df.columns: {list(biological_processes_df.columns)}")
# Out:
# biological_processes_df.shape: (318, 6)
# biological_processes_df.columns: ['Term', 'Annotated', 'Significant', 'Expected', 'Fisher Test', 'Significant Genes']

# %%
unique_terms_CB = pd.unique(biological_processes_df["Term"])
print(f"Number of unique_terms: {len(unique_terms_CB)}")
# for unique_term in unique_terms_CB: print(unique_term)
# Out:
# Number of unique_terms: 313

# %%
for term in unique_terms_CB: print(f"\t* {term}")
# Out:
# 	* plasma membrane bounded cell projection ...
# 	* cell projection organization
# 	* cellular component organization
# 	* cell development
# 	* cellular component organization or bioge...
# 	* localization
# 	* cellular component morphogenesis
# 	* nervous system development
# 	* cell morphogenesis
# 	* cytoskeleton organization
# 	* anatomical structure development
# 	* actin filament-based process
# 	* movement of cell or subcellular componen...
# 	* multicellular organism development
# 	* generation of neurons
# 	* cell projection assembly
# 	* neurogenesis
# 	* developmental process
# 	* actin cytoskeleton organization
# 	* neuron projection development
# 	* neuron development
# 	* cell adhesion
# 	* regulation of signaling
# 	* biological adhesion
# 	* neuron differentiation
# 	* system development
# 	* regulation of cell communication
# 	* neuron projection morphogenesis
# 	* regulation of small GTPase mediated sign...
# 	* cell projection morphogenesis
# 	* supramolecular fiber organization
# 	* cell part morphogenesis
# 	* regulation of cellular component organiz...
# 	* regulation of localization
# 	* ion transport
# 	* ion transmembrane transport
# 	* anatomical structure morphogenesis
# 	* microtubule-based movement
# 	* multicellular organismal process
# 	* cellular developmental process
# 	* organelle organization
# 	* intracellular signal transduction
# 	* homophilic cell adhesion via plasma memb...
# 	* cell morphogenesis involved in different...
# 	* modulation of chemical synaptic transmis...
# 	* regulation of trans-synaptic signaling
# 	* cation transmembrane transport
# 	* regulation of biological quality
# 	* positive regulation of GTPase activity
# 	* regulation of plasma membrane bounded ce...
# 	* regulation of GTPase activity
# 	* establishment of localization
# 	* small GTPase mediated signal transductio...
# 	* regulation of cell projection organizati...
# 	* cell morphogenesis involved in neuron di...
# 	* cellular component assembly
# 	* microtubule-based process
# 	* cation transport
# 	* inorganic ion transmembrane transport
# 	* cell differentiation
# 	* cilium organization
# 	* locomotion
# 	* transmembrane transport
# 	* metal ion transport
# 	* cell junction organization
# 	* cilium assembly
# 	* transport
# 	* regulation of signal transduction
# 	* regulation of multicellular organismal p...
# 	* regulation of Ras protein signal transdu...
# 	* regulation of cell development
# 	* actin filament organization
# 	* cilium movement
# 	* positive regulation of catalytic activit...
# 	* inorganic cation transmembrane transport
# 	* regulation of nervous system development
# 	* synaptic signaling
# 	* cell motility
# 	* localization of cell
# 	* regulation of neurogenesis
# 	* chemical synaptic transmission
# 	* anterograde trans-synaptic signaling
# 	* trans-synaptic signaling
# 	* cell-cell signaling
# 	* positive regulation of molecular functio...
# 	* regulation of transmembrane transport
# 	* organelle assembly
# 	* regulation of intracellular signal trans...
# 	* cell-cell adhesion via plasma-membrane a...
# 	* regulation of membrane potential
# 	* cell-cell adhesion
# 	* regulation of cellular component biogene...
# 	* regulation of transport
# 	* Ras protein signal transduction
# 	* adherens junction organization
# 	* sodium ion transmembrane transport
# 	* extracellular matrix organization
# 	* activation of GTPase activity
# 	* cellular component biogenesis
# 	* photoreceptor cell maintenance
# 	* actin filament bundle assembly
# 	* regulation of neuron differentiation
# 	* actomyosin structure organization
# 	* actin filament bundle organization
# 	* regulation of neuron projection developm...
# 	* developmental growth
# 	* sodium ion transport
# 	* regulation of ion transmembrane transpor...
# 	* positive regulation of hydrolase activit...
# 	* regulation of cellular component movemen...
# 	* cell-substrate adhesion
# 	* regulation of transporter activity
# 	* cell-matrix adhesion
# 	* axonogenesis
# 	* macromolecule localization
# 	* central nervous system development
# 	* regulation of supramolecular fiber organ...
# 	* synapse organization
# 	* dendrite extension
# 	* regulation of transmembrane transporter ...
# 	* axon development
# 	* extracellular structure organization
# 	* regulation of system process
# 	* dendrite development
# 	* cellular response to organonitrogen comp...
# 	* regulation of Rho protein signal transdu...
# 	* cellular potassium ion transport
# 	* potassium ion transmembrane transport
# 	* muscle system process
# 	* negative regulation of sodium ion transm...
# 	* regulation of organelle organization
# 	* protein polymerization
# 	* regulation of cell morphogenesis
# 	* monovalent inorganic cation transport
# 	* regulation of cell projection assembly
# 	* regulation of molecular function
# 	* enzyme linked receptor protein signaling...
# 	* muscle contraction
# 	* phosphorus metabolic process
# 	* regulation of dendrite extension
# 	* regulation of ion transport
# 	* cellular response to nitrogen compound
# 	* regulation of response to stimulus
# 	* potassium ion transport
# 	* cell migration
# 	* regulation of cation transmembrane trans...
# 	* phosphate-containing compound metabolic ...
# 	* transmembrane receptor protein tyrosine ...
# 	* lipid translocation
# 	* behavior
# 	* microtubule cytoskeleton organization
# 	* cellular localization
# 	* regulation of locomotion
# 	* phospholipid translocation
# 	* negative regulation of sodium ion transp...
# 	* inositol lipid-mediated signaling
# 	* glutamate receptor signaling pathway
# 	* animal organ development
# 	* phosphatidylinositol-mediated signaling
# 	* regulation of postsynaptic membrane pote...
# 	* regulation of anatomical structure size
# 	* regulation of cilium assembly
# 	* regulation of cellular localization
# 	* calcium ion transmembrane transport
# 	* cell-substrate junction assembly
# 	* regulation of protein localization
# 	* regulation of cell motility
# 	* regulation of catalytic activity
# 	* negative regulation of protein depolymer...
# 	* axon guidance
# 	* cell junction assembly
# 	* regulation of cytoskeleton organization
# 	* regulation of protein depolymerization
# 	* neuron projection guidance
# 	* calcium ion transport
# 	* negative regulation of supramolecular fi...
# 	* protein localization
# 	* regulation of actin filament organizatio...
# 	* axoneme assembly
# 	* signaling
# 	* cellular response to caffeine
# 	* regulation of cation channel activity
# 	* cellular response to purine-containing c...
# 	* microtubule bundle formation
# 	* multicellular organismal signaling
# 	* neuron projection extension
# 	* regulation of cell-matrix adhesion
# 	* cell surface receptor signaling pathway ...
# 	* chemical synaptic transmission, postsyna...
# 	* developmental growth involved in morphog...
# 	* regulation of cell migration
# 	* excitatory postsynaptic potential
# 	* divalent metal ion transport
# 	* cell-substrate adherens junction assembl...
# 	* focal adhesion assembly
# 	* positive regulation of cell projection o...
# 	* growth
# 	* cell communication
# 	* regulation of actin filament-based proce...
# 	* negative regulation of cytoskeleton orga...
# 	* regulation of cellular component size
# 	* adherens junction assembly
# 	* retina layer formation
# 	* regulation of developmental process
# 	* divalent inorganic cation transport
# 	* negative regulation of protein complex d...
# 	* Rho protein signal transduction
# 	* protein depolymerization
# 	* regulation of actin cytoskeleton organiz...
# 	* brain development
# 	* cellular response to stimulus
# 	* head development
# 	* regulation of metal ion transport
# 	* regulation of cell differentiation
# 	* regulation of synaptic plasticity
# 	* vesicle cytoskeletal trafficking
# 	* regulation of hydrolase activity
# 	* circulatory system process
# 	* nuclear division
# 	* cardiac conduction
# 	* regulation of multicellular organismal d...
# 	* blood circulation
# 	* dendrite morphogenesis
# 	* developmental cell growth
# 	* epithelial cell morphogenesis
# 	* chromosome separation
# 	* regulation of platelet aggregation
# 	* phospholipid transport
# 	* positive regulation of cell-matrix adhes...
# 	* regulation of neurotransmitter secretion
# 	* bone development
# 	* regulation of cell-substrate adhesion
# 	* cilium or flagellum-dependent cell motil...
# 	* cilium-dependent cell motility
# 	* positive regulation of cellular componen...
# 	* regulation of blood circulation
# 	* response to drug
# 	* cellular response to drug
# 	* positive regulation of neuron differenti...
# 	* establishment of vesicle localization
# 	* phosphatidylinositol 3-kinase signaling
# 	* vesicle localization
# 	* organelle fission
# 	* regulation of protein complex disassembl...
# 	* membrane depolarization
# 	* positive regulation of dendrite extensio...
# 	* positive regulation of calcium ion trans...
# 	* heart process
# 	* sensory perception of mechanical stimulu...
# 	* actin filament-based movement
# 	* anion transport
# 	* locomotory behavior
# 	* protein phosphorylation
# 	* negative regulation of synaptic transmis...
# 	* regulation of calcium ion transmembrane ...
# 	* protein secretion
# 	* heart contraction
# 	* muscle structure development
# 	* epithelial cell development
# 	* adult behavior
# 	* kidney development
# 	* negative regulation of platelet aggregat...
# 	* heparan sulfate proteoglycan biosyntheti...
# 	* positive regulation of neurogenesis
# 	* contractile actin filament bundle assemb...
# 	* stress fiber assembly
# 	* response to wounding
# 	* cell-cell junction organization
# 	* regulation of protein complex assembly
# 	* regulation of protein polymerization
# 	* response to organonitrogen compound
# 	* regulation of organelle assembly
# 	* regulation of platelet activation
# 	* positive regulation of cell development
# 	* wound healing
# 	* establishment or maintenance of cell pol...
# 	* learning
# 	* regulation of developmental growth
# 	* cytoskeleton-dependent intracellular tra...
# 	* negative regulation of protein complex a...
# 	* positive regulation of kinase activity
# 	* retina homeostasis
# 	* actin filament depolymerization
# 	* positive regulation of neuron projection...
# 	* tissue development
# 	* collagen fibril organization
# 	* response to stimulus
# 	* phosphorylation
# 	* visual system development
# 	* regulation of potassium ion transmembran...
# 	* neurotransmitter secretion
# 	* sperm axoneme assembly
# 	* regulation of glutamate receptor signali...
# 	* signal release
# 	* meiotic nuclear division
# 	* muscle cell development
# 	* signal release from synapse
# 	* organelle localization
# 	* regulation of membrane lipid distributio...
# 	* glycerolipid biosynthetic process
# 	* establishment of organelle localization
# 	* positive regulation of nervous system de...
# 	* eye development
# 	* heparan sulfate proteoglycan metabolic p...
# 	* response to ATP
# 	* positive regulation of multicellular org...
# 	* neurotransmitter transport
# 	* negative regulation of cellular componen...
# 	* establishment of cell polarity
# 	* retina development in camera-type eye
# 	* neuron migration
# 	* response to purine-containing compound
# 	* regulation of protein secretion

# %%
biological_processes_df
# Out:
#                                                    Term  Annotated  \
# GO.ID
# GO:0120036  plasma membrane bounded cell projection ...       1559
# GO:0030030                 cell projection organization       1598
# GO:0016043              cellular component organization       6650
# GO:0048468                             cell development       2133
# GO:0071840  cellular component organization or bioge...       6845
# ...                                                 ...        ...
# GO:0030010               establishment of cell polarity        139
# GO:0060041        retina development in camera-type eye        139
# GO:0001764                             neuron migration        145
# GO:0014074       response to purine-containing compound        145
# GO:0050708              regulation of protein secretion        282
#
#             Significant  Expected   Fisher Test  \
# GO.ID
# GO:0120036          343    196.02  1.200000e-27
# GO:0030030          349    200.92  1.700000e-27
# GO:0016043         1053    836.14  5.100000e-23
# GO:0048468          409    268.19  1.500000e-20
# GO:0071840         1065    860.66  1.800000e-20
# ...                 ...       ...           ...
# GO:0030010           31     17.48  9.600000e-04
# GO:0060041           31     17.48  9.600000e-04
# GO:0001764           32     18.23  9.700000e-04
# GO:0014074           32     18.23  9.700000e-04
# GO:0050708           54     35.46  9.900000e-04
#
#                                             Significant Genes
# GO.ID
# GO:0120036  1002:10083:10090:10100:1012:10121:10257:10300:...
# GO:0030030  1002:10083:10090:10100:1012:10121:10257:10300:...
# GO:0016043  10000:1002:1004:10049:10056:10079:1008:10082:1...
# GO:0048468  10019:1002:10083:10090:10100:1021:10300:10319:...
# GO:0071840  10000:1002:1004:10049:10056:10079:1008:10082:1...
# ...                                                       ...
# GO:0030010  10090:10806:10890:143098:1794:23094:23150:2318...
# GO:0060041  10083:10319:1826:2055:221322:221935:22882:2336...
# GO:0001764  10718:10806:116983:153090:161582:1952:2066:221...
# GO:0014074  10518:1261:1373:159:1791:2230:2889:3488:351:37...
# GO:0050708  10497:10972:11069:111:134957:1803:1814:252983:...
#
# [318 rows x 6 columns]

# %% [markdown]
# #### GO: **Celular Location**

# %%
celular_location_df = pd.read_csv(f"{input_folder}/CC_enriched_genes_entrez.txt.tsv", sep="\t", index_col=0, header="infer")
print(f"celular_location_df.shape: {celular_location_df.shape}")
print(f"celular_location_df.columns: {list(celular_location_df.columns)}")
# Out:
# celular_location_df.shape: (123, 6)
# celular_location_df.columns: ['Term', 'Annotated', 'Significant', 'Expected', 'Fisher Test', 'Significant Genes']

# %%
unique_terms_CC = pd.unique(celular_location_df["Term"])
print(f"Number of unique_terms: {len(unique_terms_CC)}")
# for unique_term in unique_terms_CC: print(unique_term)
# Out:
# Number of unique_terms: 122

# %%
celular_location_df
# Out:
#                                                Term  Annotated  Significant  \
# GO.ID
# GO:0005737                                cytoplasm      11890         1785
# GO:0042995                          cell projection       2267          470
# GO:0044444                         cytoplasmic part       9986         1518
# GO:0120025  plasma membrane bounded cell projection       2167          445
# GO:0044463                     cell projection part       1509          327
# ...                                             ...        ...          ...
# GO:0033268                          node of Ranvier         14            7
# GO:0099513             polymeric cytoskeletal fiber        747          124
# GO:0005783                    endoplasmic reticulum       1960          293
# GO:0042734                     presynaptic membrane        137           31
# GO:0032420                             stereocilium         55           16
#
#             Expected Fisher Test  \
# GO.ID
# GO:0005737   1501.93     < 1e-30
# GO:0042995    286.37     < 1e-30
# GO:0044444   1261.42     7.2e-29
# GO:0120025    273.73     1.9e-28
# GO:0044463    190.62     1.1e-24
# ...              ...         ...
# GO:0033268      1.77     0.00078
# GO:0099513     94.36     0.00078
# GO:0005783    247.59     0.00079
# GO:0042734     17.31     0.00081
# GO:0032420      6.95     0.00093
#
#                                             Significant Genes
# GO.ID
# GO:0005737  10000:10010:10019:10020:10024:10026:100271849:...
# GO:0042995  10083:1012:1021:10300:10400:10458:10497:10518:...
# GO:0044444  10010:10019:10020:10026:100271849:100271927:10...
# GO:0120025  10083:1012:1021:10300:10400:10458:10497:10518:...
# GO:0044463  10083:10300:10400:10497:10518:1063:10642:10755...
# ...                                                       ...
# GO:0033268                1739:23114:288:3786:4653:57731:6900
# GO:0099513  10300:10611:10783:11043:11076:11127:114791:127...
# GO:0005783  10026:10148:10299:10313:10345:10396:10400:1040...
# GO:0042734  1008:10497:1272:134957:1949:2066:22854:22859:2...
# GO:0032420  10083:10518:125336:2059:25861:583:64072:7399:7...
#
# [123 rows x 6 columns]

# %%
membrane_counter = 0
membrane_related = ["membrane", "cytoskeleton", "periphery"]
for term in unique_terms_CC: 
    # print(f"\t* {term}")
    for word in membrane_related: 
        if word in term: membrane_counter +=1
# print(f"membrane_counter: {membrane_counter}")

# %% [markdown]
# #### GO: **Molecular Function**

# %%
molecular_function_df = pd.read_csv(f"{input_folder}/MF_enriched_genes_entrez.txt.tsv", sep="\t", index_col=0, header="infer")
print(f"molecular_function_df.shape: {molecular_function_df.shape}")
print(f"molecular_function_df.columns: {list(molecular_function_df.columns)}")
# Out:
# molecular_function_df.shape: (92, 6)
# molecular_function_df.columns: ['Term', 'Annotated', 'Significant', 'Expected', 'Fisher Test', 'Significant Genes']

# %%
unique_terms_MF = pd.unique(molecular_function_df["Term"])
print(f"Number of unique_terms: {len(unique_terms_MF)}")
# for unique_term in unique_terms_MF: print(unique_term)
# Out:
# Number of unique_terms: 89

# %%
# for term in unique_terms_MF: print(f"\t* {term}")

# %%
molecular_function_df
# Out:
#                                                    Term  Annotated  \
# GO.ID
# GO:0008092                 cytoskeletal protein binding        985
# GO:0043168                                anion binding       2844
# GO:0003779                                actin binding        441
# GO:0043167                                  ion binding       6293
# GO:0005543                         phospholipid binding        456
# ...                                                 ...        ...
# GO:0042578          phosphoric ester hydrolase activity        372
# GO:0004674     protein serine/threonine kinase activity        391
# GO:0015077  monovalent inorganic cation transmembran...        367
# GO:0015276            ligand-gated ion channel activity        138
# GO:0022834                ligand-gated channel activity        138
#
#             Significant  Expected   Fisher Test  \
# GO.ID
# GO:0008092          248    130.35  2.100000e-25
# GO:0043168          535    376.35  3.100000e-20
# GO:0003779          123     58.36  1.300000e-16
# GO:0043167         1010    832.76  5.500000e-16
# GO:0005543          115     60.34  2.400000e-12
# ...                 ...       ...           ...
# GO:0042578           71     49.23  8.500000e-04
# GO:0004674           74     51.74  8.500000e-04
# GO:0015077           70     48.57  9.300000e-04
# GO:0015276           32     18.26  9.500000e-04
# GO:0022834           32     18.26  9.500000e-04
#
#                                             Significant Genes
# GO.ID
# GO:0008092  10083:10300:10391:10398:10458:10580:10611:1063...
# GO:0043168  10000:10020:10026:100271927:100506084:10056:10...
# GO:0003779  10083:10391:10580:10611:10755:11170:114793:119...
# GO:0043167  10000:10010:100131539:1002:10020:10026:1002719...
# GO:0005543  10026:100271927:10400:10497:1071:11188:11199:1...
# ...                                                       ...
# GO:0042578  10076:11122:1131:151742:1739:1846:1909:2203:22...
# GO:0004674  10000:1018:1021:10420:10746:10783:11214:139728...
# GO:0015077  10479:11280:1183:131096:150159:153201:157855:1...
# GO:0015276  1143:116443:1258:1261:200959:2560:2567:2741:27...
# GO:0022834  1143:116443:1258:1261:200959:2560:2567:2741:27...
#
# [92 rows x 6 columns]

# %% [markdown]
# ### **Quick trial of Text Mining clustering**
#
# Reference: https://medium.com/mlearning-ai/text-clustering-with-tf-idf-in-python-c94cd26a31e7

# %%
def preprocess_text(text: str, remove_stopwords: bool) -> str:
    
    """
    This function cleans the input text by
    - removing links
    - removing special chars
    - removing numbers
    - removing stopwords
    - transforming in lower case
    - removing excessive whitespaces
    Arguments:
        text (str): text to clean
        remove_stopwords (bool): remove stopwords or not
    Returns:
        str: cleaned text"""
        
    # remove links
    text = re.sub(r"http\S+", "", text)
    # remove numbers and special chars
    text = re.sub("[^A-Za-z]+", " ", text)
    # remove stopwords
    if remove_stopwords:
        # 1. creates tokens
        tokens = nltk.word_tokenize(text)
        # 2. checks if token is a stopword and removes it
        tokens = [w for w in tokens if not w.lower() in stopwords.words("english")]
        # 3. joins all tokens again
        text = " ".join(tokens)
    # returns cleaned text
    text = text.lower().strip()
    return text
  
def get_top_keywords(n_terms):
    """This function returns the keywords for each centroid of the KMeans"""
    df = pd.DataFrame(X.todense()).groupby(clusters).mean() # groups tf idf vector per cluster
    terms = vectorizer.get_feature_names_out() # access to tf idf terms
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([terms[t] for t in np.argsort(r)[-n_terms:]])) # for each row of the dataframe, find the n terms that have the highest tf idf score

# %%
# import required sklearn libs
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# import other required libs
import pandas as pd
import numpy as np

# string manipulation libs
import re
import string
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords

# viz libs
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(biological_processes_df["Term"], columns=["Term"])
df['cleaned'] = df['Term'].apply(lambda x: preprocess_text(x, remove_stopwords=True))

# initialize vectorizer
vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5, max_df=0.95)
# fit_transform applies TF-IDF to clean texts - we save the array of vectors in X
X = vectorizer.fit_transform(df['cleaned'])

# initialize KMeans with 3 clusters
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)
clusters = kmeans.labels_
biological_processes_df["cluster"] = clusters

# initialize PCA with 2 components
pca = PCA(n_components=2, random_state=42)
# pass X to the pca
pca_vecs = pca.fit_transform(X.toarray())
# save the two dimensions in x0 and x1
x0 = pca_vecs[:, 0]
x1 = pca_vecs[:, 1]

# assign clusters and PCA vectors to columns in the original dataframe
df['cluster'] = clusters
df['x0'] = x0
df['x1'] = x1

# cluster_map = {0: "membrane organization", 1: "neurogenesis", 2: "cell organization"} # mapping found through get_top_keywords
# df['cluster'] = df['cluster'].map(cluster_map)

# set image size
plt.figure(figsize=(12, 7))
# set title
plt.title("Grouping TF-IDF + KMeans 20newsgroup", fontdict={"fontsize": 18})
# set axes names
plt.xlabel("X0", fontdict={"fontsize": 16})
plt.ylabel("X1", fontdict={"fontsize": 16})
#  create scatter plot with seaborn, where hue is the class used to group the data
sns.scatterplot(data=df, x='x0', y='x1', hue='cluster', palette="viridis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <module>
#      12 import re
#      13 import string
# ---> 14 import nltk
#      15 nltk.download('punkt')
#      16 nltk.download('stopwords')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
# for cluster in clusters:
#     print(f"cluster: {cluster}")
#     df = biological_processes_df[biological_processes_df["cluster"] == cluster]
#     print(df["Term"])
#     print()

# %% [markdown]
# ### (2) **UCSC annotation** (original)

# %%
input_folder="my_results"  # Update input folder
ucsc_annotation_df = pd.read_csv(f"{input_folder}/UCSC_common_segments_annotated.bed", sep="\t", index_col=None, header=None)
print(f"ucsc_annotation_df.shape: {ucsc_annotation_df.shape}")
# Out:
# ucsc_annotation_df.shape: (8066, 4)

# %%
# NaN values in annotation column
print(f"NaN values in annotation: {ucsc_annotation_df[3].isnull().sum()} in {ucsc_annotation_df.shape[0]}")

# Change NaN values for desired value
desired_value="NoGene"
ucsc_annotation_df = ucsc_annotation_df.fillna(desired_value, axis=1)

# Unique identifiers
unique_ids = pd.unique(ucsc_annotation_df[3])
unique_ids = np.delete(unique_ids, np.where(unique_ids == "NoGene"))
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# NaN values in annotation: 4800 in 8066
# Number of different gene IDs: 2617

# %% [markdown]
# ### (3) **UCSC annotation** (coding)

# %% [markdown]
# Pendiente comprender significado de dos archivos.

# %%
input_folder="input/forExercise2"  # Update input folder
ucsc_annotation_codingComplete = pd.read_csv(f"{input_folder}/protCodGenesComplete", sep="\t", index_col=None, header=None)
print(f"ucsc_annotation_codingComplete.shape: {ucsc_annotation_codingComplete.shape}")
ucsc_annotation_codingComplete
# Out:
# ucsc_annotation_codingComplete.shape: (21461, 12)
#                          0         1         2               3   4  5   \
# 0                      chr1  66999835  67216822     NM_032291.4   0  +
# 1                      chr1   8378173   8404225  NM_001080397.3   0  +
# 2                      chr1  16767218  16786573     NM_018090.5   0  +
# 3                      chr1  25071937  25170812     NM_013943.3   0  +
# 4                      chr1  33546753  33589093     NM_052998.4   0  +
# ...                     ...       ...       ...             ...  .. ..
# 21456    chr22_kb663609_alt         1      1783  NM_001002034.3   0  +
# 21457    chr22_kb663609_alt      2044      6629     NM_033318.5   0  +
# 21458    chr22_kb663609_alt      7870     13117     NM_002490.6   0  -
# 21459    chr22_kb663609_alt     48825     53137     NM_000106.6   0  -
# 21460  chr7_gl000195_random     42937     86735  NM_001347681.2   0  -
#
#              6         7   8   9   \
# 0      67000041  67208778   0  25
# 1       8384389   8404073   0   9
# 2      16767256  16785385   0   8
# 3      25072044  25167428   0   6
# 4      33547850  33585783   0  12
# ...         ...       ...  ..  ..
# 21456         1       418   0   1
# 21457      2113      4407   0   3
# 21458      8527     13089   0   3
# 21459     48900     53118   0   9
# 21460     44723     49117   0   3
#
#                                                       10  \
# 0      216,64,25,72,57,55,176,12,12,25,52,86,93,75,50...
# 1                     73,421,93,225,728,154,177,206,419,
# 2                        130,101,105,82,109,178,76,1237,
# 3                              179,110,126,107,182,3549,
# 4      142,121,212,177,174,173,135,166,163,113,215,3449,
# ...                                                  ...
# 21456                                              1782,
# 21457                                      255,141,1166,
# 21458                                       789,116,167,
# 21459               254,142,188,142,177,161,153,172,199,
# 21460                                      1986,165,218,
#
#                                                       11
# 0      0,91694,98917,101791,105624,108657,109391,1263...
# 1        0,6192,7184,7704,12095,17323,19702,21379,25633,
# 2               0,2908,7146,7336,8369,11114,15094,18118,
# 3                       0,52295,68647,81563,94413,95326,
# 4      0,235,448,1025,2801,10897,12129,13395,15554,16...
# ...                                                  ...
# 21456                                                 0,
# 21457                                       0,2225,3419,
# 21458                                       0,1534,5080,
# 21459           0,352,948,1343,1675,2285,2534,3239,4113,
# 21460                                      0,6017,43580,
#
# [21461 rows x 12 columns]

# %%
# Unique identifiers
unique_ids = pd.unique(ucsc_annotation_codingComplete[3])
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# Number of different gene IDs: 19199

# %%
input_folder="input/forExercise2"  # Update input folder
ucsc_annotation_codingExons = pd.read_csv(f"{input_folder}/protCodGenesONLYEXONS", sep="\t", index_col=None, header=None)
print(f"ucsc_annotation_codingExons.shape: {ucsc_annotation_codingExons.shape}")
ucsc_annotation_codingExons
# Out:
# ucsc_annotation_codingExons.shape: (210136, 6)
#                            0         1         2  \
# 0                       chr1  67000041  67000051
# 1                       chr1  67091529  67091593
# 2                       chr1  67098752  67098777
# 3                       chr1  67101626  67101698
# 4                       chr1  67105459  67105516
# ...                      ...       ...       ...
# 210131    chr22_kb663609_alt     51359     51512
# 210132    chr22_kb663609_alt     52064     52236
# 210133    chr22_kb663609_alt     52938     53118
# 210134  chr7_gl000195_random     44723     44923
# 210135  chr7_gl000195_random     48954     49117
#
#                                                         3  4  5
# 0                     NM_032291.4_cds_0_0_chr1_67000042_f  0  +
# 1                     NM_032291.4_cds_1_0_chr1_67091530_f  0  +
# 2                     NM_032291.4_cds_2_0_chr1_67098753_f  0  +
# 3                     NM_032291.4_cds_3_0_chr1_67101627_f  0  +
# 4                     NM_032291.4_cds_4_0_chr1_67105460_f  0  +
# ...                                                   ... .. ..
# 210131     NM_000106.6_cds_6_0_chr22_kb663609_alt_51360_r  0  -
# 210132     NM_000106.6_cds_7_0_chr22_kb663609_alt_52065_r  0  -
# 210133     NM_000106.6_cds_8_0_chr22_kb663609_alt_52939_r  0  -
# 210134  NM_001347681.2_cds_0_0_chr7_gl000195_random_44...  0  -
# 210135  NM_001347681.2_cds_1_0_chr7_gl000195_random_48...  0  -
#
# [210136 rows x 6 columns]

# %%
# Unique identifiers
unique_ids = pd.unique(ucsc_annotation_codingExons[3])
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# Number of different gene IDs: 210136

# %% [markdown]
# ### (4) **UCSC annotation** (new in input, other BED features)
#
# See percentage criterion, based on -f option in `bedtools`, in summaryBiologicalInterpretation.ipynb.
#
# If we want a minimum overlap correspondent to the number of bases of the main CTCF DNA binding motif (17 bp) [**refs. 3 & 4**], we would need to know the average length of segments in the common_segments.bed file (...).

# %% [markdown]
# #### **3UTR**

# %%
input_folder="input/bedFiles_various_genefeatures"  # Update input folder
utr3 = pd.read_csv(f"{input_folder}/3UTR", sep="\t", index_col=None, header=None)
print(f"utr3.shape: {utr3.shape}")
utr3
# Out:
# utr3.shape: (22127, 6)
#                           0         1         2  \
# 0                      chr1  67208778  67216822
# 1                      chr1   8404073   8404225
# 2                      chr1  16785385  16786573
# 3                      chr1  25167428  25170812
# 4                      chr1  33585783  33589093
# ...                     ...       ...       ...
# 22122    chr22_kb663609_alt      4407      4410
# 22123    chr22_kb663609_alt      5463      6629
# 22124    chr22_kb663609_alt      7870      8527
# 22125    chr22_kb663609_alt     48825     48900
# 22126  chr7_gl000195_random     42937     44723
#
#                                                        3  4  5
# 0                  NM_032291.4_utr3_24_0_chr1_67208779_f  0  +
# 1                 NM_001080397.3_utr3_8_0_chr1_8404074_f  0  +
# 2                   NM_018090.5_utr3_7_0_chr1_16785386_f  0  +
# 3                   NM_013943.3_utr3_5_0_chr1_25167429_f  0  +
# 4                  NM_052998.4_utr3_11_0_chr1_33585784_f  0  +
# ...                                                  ... .. ..
# 22122     NM_033318.5_utr3_1_0_chr22_kb663609_alt_4408_f  0  +
# 22123     NM_033318.5_utr3_2_0_chr22_kb663609_alt_5464_f  0  +
# 22124     NM_002490.6_utr3_0_0_chr22_kb663609_alt_7871_r  0  -
# 22125    NM_000106.6_utr3_0_0_chr22_kb663609_alt_48826_r  0  -
# 22126  NM_001347681.2_utr3_0_0_chr7_gl000195_random_4...  0  -
#
# [22127 rows x 6 columns]

# %%
# Unique identifiers
unique_ids = pd.unique(utr3[3])
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# Number of different gene IDs: 22127

# %%
min_overlap=0.03
input_folder = "bedFiles_various_genefeatures"
evaluate = "3UTR"
input_file = f"{input_folder}/{evaluate}"
n_segments = !./BiologicalInterpretation/step2.sh $min_overlap $input_file
print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <module>
#       4 input_file = f"{input_folder}/{evaluate}"
#       5 n_segments = get_ipython().getoutput('./BiologicalInterpretation/step2.sh $min_overlap $input_file')
# ----> 6 print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
#
# ValueError: invalid literal for int() with base 10: '/bin/bash: línea 1: ./BiologicalInterpretation/step2.sh: Permiso denegado'

# %% [markdown]
# #### **5UTR**

# %%
input_folder="input/bedFiles_various_genefeatures"  # Update input folder
utr5 = pd.read_csv(f"{input_folder}/5UTR", sep="\t", index_col=None, header=None)
print(f"utr5.shape: {utr5.shape}")
utr5
# Out:
# utr5.shape: (31098, 6)
#                           0         1         2  \
# 0                      chr1  66999835  67000041
# 1                      chr1   8378173   8378246
# 2                      chr1   8384365   8384389
# 3                      chr1  16767218  16767256
# 4                      chr1  25071937  25072044
# ...                     ...       ...       ...
# 31093    chr22_kb663609_alt      2044      2113
# 31094    chr22_kb663609_alt     13089     13117
# 31095    chr22_kb663609_alt     53118     53137
# 31096  chr7_gl000195_random     49117     49119
# 31097  chr7_gl000195_random     86517     86735
#
#                                                        3  4  5
# 0                   NM_032291.4_utr5_0_0_chr1_66999836_f  0  +
# 1                 NM_001080397.3_utr5_0_0_chr1_8378174_f  0  +
# 2                 NM_001080397.3_utr5_1_0_chr1_8384366_f  0  +
# 3                   NM_018090.5_utr5_0_0_chr1_16767219_f  0  +
# 4                   NM_013943.3_utr5_0_0_chr1_25071938_f  0  +
# ...                                                  ... .. ..
# 31093     NM_033318.5_utr5_0_0_chr22_kb663609_alt_2045_f  0  +
# 31094    NM_002490.6_utr5_2_0_chr22_kb663609_alt_13090_r  0  -
# 31095    NM_000106.6_utr5_8_0_chr22_kb663609_alt_53119_r  0  -
# 31096  NM_001347681.2_utr5_1_0_chr7_gl000195_random_4...  0  -
# 31097  NM_001347681.2_utr5_2_0_chr7_gl000195_random_8...  0  -
#
# [31098 rows x 6 columns]

# %%
# Unique identifiers
unique_ids = pd.unique(utr5[3])
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# Number of different gene IDs: 31098

# %%
# min_overlap=0.001
input_folder = "bedFiles_various_genefeatures"
evaluate = "5UTR"
input_file = f"{input_folder}/{evaluate}"
n_segments = !./BiologicalInterpretation/step2.sh $min_overlap $input_file
print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
utr3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <module>
#       4 input_file = f"{input_folder}/{evaluate}"
#       5 n_segments = get_ipython().getoutput('./BiologicalInterpretation/step2.sh $min_overlap $input_file')
# ----> 6 print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
#       7 utr3
#
# ValueError: invalid literal for int() with base 10: '/bin/bash: línea 1: ./BiologicalInterpretation/step2.sh: Permiso denegado'

# %% [markdown]
# #### **Introns**

# %%
input_folder="input/bedFiles_various_genefeatures"  # Update input folder
introns = pd.read_csv(f"{input_folder}/introns", sep="\t", index_col=None, header=None)
print(f"introns.shape: {introns.shape}")
introns
# Out:
# introns.shape: (200135, 6)
#                            0         1         2  \
# 0                       chr1  67000051  67091529
# 1                       chr1  67091593  67098752
# 2                       chr1  67098777  67101626
# 3                       chr1  67101698  67105459
# 4                       chr1  67105516  67108492
# ...                      ...       ...       ...
# 200130    chr22_kb663609_alt     51271     51359
# 200131    chr22_kb663609_alt     51512     52064
# 200132    chr22_kb663609_alt     52236     52938
# 200133  chr7_gl000195_random     44923     48954
# 200134  chr7_gl000195_random     49119     86517
#
#                                                         3  4  5
# 0                  NM_032291.4_intron_0_0_chr1_67000052_f  0  +
# 1                  NM_032291.4_intron_1_0_chr1_67091594_f  0  +
# 2                  NM_032291.4_intron_2_0_chr1_67098778_f  0  +
# 3                  NM_032291.4_intron_3_0_chr1_67101699_f  0  +
# 4                  NM_032291.4_intron_4_0_chr1_67105517_f  0  +
# ...                                                   ... .. ..
# 200130  NM_000106.6_intron_5_0_chr22_kb663609_alt_51272_r  0  -
# 200131  NM_000106.6_intron_6_0_chr22_kb663609_alt_51513_r  0  -
# 200132  NM_000106.6_intron_7_0_chr22_kb663609_alt_52237_r  0  -
# 200133  NM_001347681.2_intron_0_0_chr7_gl000195_random...  0  -
# 200134  NM_001347681.2_intron_1_0_chr7_gl000195_random...  0  -
#
# [200135 rows x 6 columns]

# %%
# min_overlap=0.001
input_folder = "bedFiles_various_genefeatures"
evaluate = "introns"
input_file = f"{input_folder}/{evaluate}"
n_segments = !./BiologicalInterpretation/step2.sh $min_overlap $input_file
print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <module>
#       4 input_file = f"{input_folder}/{evaluate}"
#       5 n_segments = get_ipython().getoutput('./BiologicalInterpretation/step2.sh $min_overlap $input_file')
# ----> 6 print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
#
# ValueError: invalid literal for int() with base 10: '/bin/bash: línea 1: ./BiologicalInterpretation/step2.sh: Permiso denegado'

# %%
# Unique identifiers
unique_ids = pd.unique(introns[3])
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# Number of different gene IDs: 200135

# %% [markdown]
# #### **Upstream region of genes**

# %%
input_folder="input/bedFiles_various_genefeatures"  # Update input folder
upstreamGenes = pd.read_csv(f"{input_folder}/upstreamGenes", sep="\t", index_col=None, header=None)
print(f"upstreamGenes.shape: {upstreamGenes.shape}")
upstreamGenes
# Out:
# upstreamGenes.shape: (21458, 6)
#                           0         1         2  \
# 0                      chr1  66999635  66999835
# 1                      chr1   8377973   8378173
# 2                      chr1  16767018  16767218
# 3                      chr1  25071737  25071937
# 4                      chr1  33546553  33546753
# ...                     ...       ...       ...
# 21453    chr22_kb663609_alt         0         1
# 21454    chr22_kb663609_alt      1844      2044
# 21455    chr22_kb663609_alt     13117     13317
# 21456    chr22_kb663609_alt     53137     53337
# 21457  chr7_gl000195_random     86735     86935
#
#                                                        3  4  5
# 0                     NM_032291.4_up_200_chr1_66999636_f  0  +
# 1                   NM_001080397.3_up_200_chr1_8377974_f  0  +
# 2                     NM_018090.5_up_200_chr1_16767019_f  0  +
# 3                     NM_013943.3_up_200_chr1_25071738_f  0  +
# 4                     NM_052998.4_up_200_chr1_33546554_f  0  +
# ...                                                  ... .. ..
# 21453    NM_001002034.3_up_200_chr22_kb663609_alt_-198_f  0  +
# 21454       NM_033318.5_up_200_chr22_kb663609_alt_1845_f  0  +
# 21455      NM_002490.6_up_200_chr22_kb663609_alt_13118_r  0  -
# 21456      NM_000106.6_up_200_chr22_kb663609_alt_53138_r  0  -
# 21457  NM_001347681.2_up_200_chr7_gl000195_random_867...  0  -
#
# [21458 rows x 6 columns]

# %%
# Unique identifiers
unique_ids = pd.unique(upstreamGenes[3])
print(f"Number of different gene IDs: {len(unique_ids)}")
# Out:
# Number of different gene IDs: 21458

# %%
# min_overlap=0.001
input_folder = "bedFiles_various_genefeatures"
evaluate = "upstreamGenes"
input_file = f"{input_folder}/{evaluate}"
n_segments = !./BiologicalInterpretation/step2.sh $min_overlap $input_file
print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <module>
#       4 input_file = f"{input_folder}/{evaluate}"
#       5 n_segments = get_ipython().getoutput('./BiologicalInterpretation/step2.sh $min_overlap $input_file')
# ----> 6 print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
#
# ValueError: invalid literal for int() with base 10: '/bin/bash: línea 1: ./BiologicalInterpretation/step2.sh: Permiso denegado'

# %% [markdown]
# ### (3) **Methylation**

# %%
# min_overlap=0.001
input_folder = "forExercise6"
evaluate = "hypoBED"
input_file = f"{input_folder}/{evaluate}"
n_segments = !./BiologicalInterpretation/step2.sh $min_overlap $input_file
print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <module>
#       4 input_file = f"{input_folder}/{evaluate}"
#       5 n_segments = get_ipython().getoutput('./BiologicalInterpretation/step2.sh $min_overlap $input_file')
# ----> 6 print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
#
# ValueError: invalid literal for int() with base 10: '/bin/bash: línea 1: ./BiologicalInterpretation/step2.sh: Permiso denegado'

# %%
# min_overlap=0.001
input_folder = "forExercise6"
evaluate = "hyperBED"
input_file = f"{input_folder}/{evaluate}"
n_segments = !./BiologicalInterpretation/step2.sh $min_overlap $input_file
print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <module>
#       4 input_file = f"{input_folder}/{evaluate}"
#       5 n_segments = get_ipython().getoutput('./BiologicalInterpretation/step2.sh $min_overlap $input_file')
# ----> 6 print(f"Perc. of overlapping between working segments and {evaluate} regions: {round((int(n_segments[0])/8022)*100, 2)}%")
#
# ValueError: invalid literal for int() with base 10: '/bin/bash: línea 1: ./BiologicalInterpretation/step2.sh: Permiso denegado'

# %% [markdown]
# ### **Summary Table on annotations**

# %% [markdown]
# | **Feature**                                                      | Overlap in terms of length | Overlap in terms of number of segments (no min. overlap) | Overlap in terms of number of segments (-f 0.03) |
# |------------------------------------------------------------------|----------------------------|----------------------------------------------------------|--------------------------------------------------|
# | Percentage of coding genes with CTCF segments                    | 39.73%                     |                                                          |                                                  |
# | Percentage of exons of coding genes with CTCF segments           | 1.52%                      |                                                          |                                                  |
# | Percentage of introns of coding genes with CTCF segments         | 35.70%                     | 42.2%                                                    | 41.85%                                           |
# | Percentage of 3 UTR of coding genes with CTCF segments           | 2.36%                      | 3.63%                                                    | 3.48%                                            |
# | Percentage of 5 UTR of coding genes with CTCF segments           | 0.14%                      | 0.82%                                                    | 0.72%                                            |
# | Percentage of upstream 200 bp of coding genes with CTCF segments | 0.22%                      | 1.07%                                                    | 1.02%                                            |
# | Percentage of overlapping with DNaseI                            | 25.88%                     | 55.51%                                                   | 55.19%                                           |
# | Percentage of overlapping with <span style="color:red">hypermetylated</span> regions           | 80.87%                     | 93.63%                                                   | 92.47%                                           |
# | Percentage of overlapping with <span style="color:red">hypomethylated</span> regions            | 2.55%                      | 7.21%                                                    | 6.49%                                            |

# %% [markdown]
# **Considerations**:
#
# * Overlap in terms of length from Inés, overlap in terms of number of segments from Iván (in case of doubts with the approaches).
#
# * The approaches are different even if the final percentages are similar: it might not be the same an overlap between one of our working segments and any of the reported features *in an insignificant region of our segment* vs. *in the actual CTCF DNA-binding motif of our segment*. However, we cannot be sure whether we are capturing this CTCF DNA binding motif with any of both approaches.
#
# * Hypo/ hypermethylated percentages have to be corrected.

# %% [markdown]
# ## **References**
#
# (0) CTCF summary
#
# (1) Lu Y, Shan G, Xue J, Chen C, Zhang C. *Defining the multivalent functions of CTCF from chromatin state and three-dimensional chromatin interactions*. Nucleic Acids Res. 2016 Jul 27;44(13):6200-12. doi: 10.1093/nar/gkw249. Epub 2016 Apr 11. PMID: 27067545; PMCID: PMC5291250. \label{1}
#
# (2) Xi H, Shulha HP, Lin JM, Vales TR, Fu Y, Bodine DM, et al. (2007) *Identification and Characterization of Cell Type–Specific and Ubiquitous Chromatin Regulatory Structures in the Human Genome*. PLoS Genet 3(8): e136. https://doi.org/10.1371/journal.pgen.0030136. \label{2}
#
# (3) Cuddapah S, Jothi R, Schones DE, Roh TY, Cui K, Zhao K. *Global analysis of the insulator binding protein CTCF in chromatin barrier regions reveals demarcation of active and repressive domains*. Genome Res. 2009 Jan;19(1):24-32. doi: 10.1101/gr.082800.108. Epub 2008 Dec 3. PMID: 19056695; PMCID: PMC2612964. \label{3}
#
# (4) Ong, CT., Corces, V. *CTCF: an architectural protein bridging genome topology and function*. Nat Rev Genet 15, 234–246 (2014). https://doi.org/10.1038/nrg3663. \label{4}
#
# (5) Ghirlando R, Felsenfeld G. CTCF: making the right connections. Genes Dev. 2016 Apr 15;30(8):881-91. doi: 10.1101/gad.277863.116. PMID: 27083996; PMCID: PMC4840295. \label{5}
